# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.multivariate.manova import MANOVA
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('data/05-primas_norm_est_1.csv',index_col=0)
df.head(10)
# Out:
#       index       age     sex       bmi  children smoker     region  \
# 0 -1.654590 -0.683871    male -1.697491 -1.011604     no  northwest
# 1 -1.639514  1.268419  female -1.120191 -1.011604     no  northwest
# 2 -1.634489  1.413033  female -1.037325 -1.011604    yes  southeast
# 3 -1.626951 -1.117713    male  1.879556 -1.011604    yes  southeast
# 4 -1.614388 -0.900792    male  0.621835 -1.011604    yes  southwest
# 5 -1.604338 -0.611564  female -0.000580 -0.120740    yes  northeast
# 6 -1.589262 -0.828485    male  0.805982  0.770124    yes  southwest
# 7 -1.586749 -1.479248    male  0.677079 -1.011604    yes  southwest
# 8 -1.576699 -1.045406    male  0.824397 -0.120740    yes  southwest
# 9 -1.566648 -0.539257    male  0.874116 -0.120740    yes  northeast
#
#    charges_Sklearn
# 0         0.045128
# 1         0.203687
# 2         0.178221
# 3         0.447938
# 4         0.384541
# 5         0.404294
# 6         0.427354
# 7         0.355934
# 8         0.712622
# ...

# %%
df.isnull().sum()
# Out:
# index              0
# age                0
# sex                0
# bmi                0
# children           0
# smoker             0
# region             0
# charges_Sklearn    0
# dtype: int64

# %%
df.head()
# Out:
#       index       age     sex       bmi  children smoker     region  \
# 0 -1.654590 -0.683871    male -1.697491 -1.011604     no  northwest
# 1 -1.639514  1.268419  female -1.120191 -1.011604     no  northwest
# 2 -1.634489  1.413033  female -1.037325 -1.011604    yes  southeast
# 3 -1.626951 -1.117713    male  1.879556 -1.011604    yes  southeast
# 4 -1.614388 -0.900792    male  0.621835 -1.011604    yes  southwest
#
#    charges_Sklearn
# 0         0.045128
# 1         0.203687
# 2         0.178221
# 3         0.447938
# 4         0.384541

# %% [markdown]
# Happy coding 🤯📊

# %% [markdown]
# # Pair Programming ANOVA

# %% [markdown]
# ## Ana Campos y Ana González

# %% [markdown]
# En el pair programming de hoy usaremos el set de datos que guardastéis en el pair programming de normalización y estandarización.
#
# Hasta ahora habéis estado evaluando las características de vuestro set de datos y habéis hecho una gran exploración, es el momento de hacer vuestro primer ANOVA! En el ejercicio de hoy tendréis que hacer un ANOVA con vuestro datos y hacer una interpretación de los resultados.

# %%
mi_primera_anova = ols('charges_Sklearn ~ 	age	+sex+	bmi+	children	+smoker	+region', data=df).fit()
sm.stats.anova_lm(mi_primera_anova)
# Out:
#              df    sum_sq   mean_sq           F        PR(>F)
# sex         1.0  0.068743  0.068743    3.128565  7.808610e-02
# smoker      1.0  2.666187  2.666187  121.341332  1.812434e-23
# region      3.0  0.385734  0.128578    5.851737  6.973855e-04
# age         1.0  0.183631  0.183631    8.357271  4.160990e-03
# bmi         1.0  4.068949  4.068949  185.182672  2.586568e-32
# children    1.0  0.001422  0.001422    0.064712  7.993964e-01
# Residual  264.0  5.800772  0.021973         NaN           NaN

# %% [markdown]
# Si PR es >=0.05, nuetsras variables predictoras influyen en nuestra variable respuesta, por lo que vemos, que todas nuestras variables, influyen 'charges'.

# %%
mi_primera_anova.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        charges_Sklearn   R-squared:                       0.560
# Model:                            OLS   Adj. R-squared:                  0.546
# Method:                 Least Squares   F-statistic:                     41.95
# Date:                Mon, 23 Jan 2023   Prob (F-statistic):           6.70e-43
# Time:                        10:25:18   Log-Likelihood:                 138.36
# No. Observations:                 273   AIC:                            -258.7
# Df Residuals:                     264   BIC:                            -226.2
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Podemos que ver que todas nuestras variables predictoras excepto sexo (masculino), tienen relación positiva, si aumentan, aumenta el valor de 'charges. El resto la tienen negativa, a medida que aumentan, disminuye el valor de 'charges'.
# Con p-value<0.05 tenemos edad, bmi, fumadores, rechazamos H0, nuestras variables predictoras tienen efecto en nuestra variable respuesta.

# %% [markdown]
# 📌 NOTA Puede que vuestros datos no se ajusten o no cumplan todas las asunciones, no pasa nada, haced el ANOVA e interpretad los resultados. En próximas lecciones aprenderemos que podemos hacer cuando nos encontramos en esta situación.
