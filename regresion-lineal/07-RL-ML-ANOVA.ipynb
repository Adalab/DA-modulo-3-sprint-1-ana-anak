# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.multivariate.manova import MANOVA
from sklearn.preprocessing import StandardScaler
# Out:
# /home/analab/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# /home/analab/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %%
df=pd.read_csv('data/05-primas_norm_est_1.csv',index_col=0)
df.head(10)
# Out:
#         age     sex       bmi  children smoker     region  charges_Sklearn
# 0 -1.387916  female -0.380152 -0.885991    yes  southwest         0.836552
# 1 -1.459488    male  0.611376 -0.069805     no  southeast         0.032037
# 2 -0.743769    male  0.481312  1.562566     no  southeast         0.176597
# 3 -0.457482    male -0.214616 -0.885991     no  northwest         0.145677
# 4 -0.529054  female -0.745008 -0.885991     no  southeast         0.139827
# 5  0.544525  female  0.555635 -0.069805     no  southeast         0.377794
# 6 -0.099622  female -0.407179  1.562566     no  northwest         0.326895
# 7 -0.099622    male -0.054147  0.746380     no  northeast         0.280453
# 8 -0.958485    male -0.663929 -0.885991     no  northeast         0.084883
# 9 -1.101629    male  0.717793 -0.885991     no  southwest         0.037413

# %%
df.isnull().sum()
# Out:
# age                0
# sex                0
# bmi                0
# children           0
# smoker             0
# region             0
# charges_Sklearn    0
# dtype: int64

# %%
df.head()
# Out:
#         age     sex       bmi  children smoker     region  charges_Sklearn
# 0 -1.387916  female -0.380152 -0.885991    yes  southwest         0.836552
# 1 -1.459488    male  0.611376 -0.069805     no  southeast         0.032037
# 2 -0.743769    male  0.481312  1.562566     no  southeast         0.176597
# 3 -0.457482    male -0.214616 -0.885991     no  northwest         0.145677
# 4 -0.529054  female -0.745008 -0.885991     no  southeast         0.139827

# %% [markdown]
# Happy coding 🤯📊

# %% [markdown]
# # Pair Programming ANOVA

# %% [markdown]
# ## Ana Campos y Ana González

# %% [markdown]
# En el pair programming de hoy usaremos el set de datos que guardastéis en el pair programming de normalización y estandarización.
#
# Hasta ahora habéis estado evaluando las características de vuestro set de datos y habéis hecho una gran exploración, es el momento de hacer vuestro primer ANOVA! En el ejercicio de hoy tendréis que hacer un ANOVA con vuestro datos y hacer una interpretación de los resultados.

# %%
mi_primera_anova = ols('charges_Sklearn ~ 	age	+sex+	bmi+	children	+smoker	+region', data=df).fit()
sm.stats.anova_lm(mi_primera_anova)
# Out:
#               df     sum_sq    mean_sq            F         PR(>F)
# sex          1.0   0.234488   0.234488    16.567408   5.045625e-05
# smoker       1.0  16.590362  16.590362  1172.166755  2.266356e-173
# region       3.0   0.201258   0.067086     4.739866   2.731763e-03
# age          1.0  33.436069  33.436069  2362.374463  1.633208e-271
# bmi          1.0   0.137200   0.137200     9.693634   1.898881e-03
# children     1.0   1.024480   1.024480    72.383046   6.006055e-17
# Residual  1055.0  14.932033   0.014154          NaN            NaN

# %% [markdown]
# Si PR es >=0.05, nuetsras variables predictoras influyen en nuestra variable respuesta, por lo que vemos, que todas nuestras variables, influyen 'charges'.

# %%
mi_primera_anova.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        charges_Sklearn   R-squared:                       0.776
# Model:                            OLS   Adj. R-squared:                  0.774
# Method:                 Least Squares   F-statistic:                     455.9
# Date:                Wed, 25 Jan 2023   Prob (F-statistic):               0.00
# Time:                        10:40:08   Log-Likelihood:                 759.91
# No. Observations:                1064   AIC:                            -1502.
# Df Residuals:                    1055   BIC:                            -1457.
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.3575      0.008     42.795      0.000       0.341       0.374
# sex[T.male]            -0.0247      0.007     -3.379      0.001      -0.039      -0.010
# smoker[T.yes]           0.6905      0.016     42.380      0.000       0.659       0.722
# region[T.northwest]    -0.0133      0.010     -1.269      0.205      -0.034       0.007
# region[T.southeast]    -0.0323      0.011     -3.031      0.003      -0.053      -0.011
# region[T.southwest]    -0.0427      0.010     -4.090      0.000      -0.063      -0.022
# age                     0.1781      0.004     47.514      0.000       0.171       0.185
# bmi                     0.0126      0.004      3.197      0.001       0.005       0.020
# children                0.0311      0.004      8.508      0.000       0.024       0.038
# ==============================================================================
# Omnibus:                     1011.007   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            28219.099
# Skew:                           4.599   Prob(JB):                         0.00
# Kurtosis:                      26.493   Cond. No.                         5.56
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Podemos que ver que todas nuestras variables predictoras excepto sexo (masculino), tienen relación positiva, si aumentan, aumenta el valor de 'charges. El resto la tienen negativa, a medida que aumentan, disminuye el valor de 'charges'.
# Con p-value<0.05 tenemos edad, bmi, fumadores, rechazamos H0, nuestras variables predictoras tienen efecto en nuestra variable respuesta.

# %% [markdown]
# 📌 NOTA Puede que vuestros datos no se ajusten o no cumplan todas las asunciones, no pasa nada, haced el ANOVA e interpretad los resultados. En próximas lecciones aprenderemos que podemos hacer cuando nos encontramos en esta situación.
